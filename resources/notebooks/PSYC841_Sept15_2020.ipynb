# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu = 3
sig2 = 10

xs = np.arange(-100,100,.1)

# %%
xs

# %%
ys = norm.pdf(xs, mu, sig2)

# %%
ys

# %%
plt.plot(xs,ys)
